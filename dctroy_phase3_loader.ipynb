# %% [markdown]
# # DCTroy Phase 3 Repository Loader
#
# This notebook clones the DCTroy Phase 3 repository and sets up the environment for running comparative evaluation experiments.
#
# Repository: https://github.com/StackOfZach/dctroy_phase3.git

# %%
# Clean up any existing directories
# !rm -rf dctroy_phase3
# !rm -rf project_dctroy

# %% [markdown]
# ## Clone Repository
#
# If your repository is **public**, no token is needed.
# If your repository is **private**, uncomment and set your GitHub token below.

# %%
import os

# Repository configuration
GITHUB_REPO_OWNER = "StackOfZach"
REPO_NAME = "dctroy_phase3"
REPO_DIR = "dctroy_phase3"

# ===== FOR PUBLIC REPOS (default) =====
REPO_URL = f"https://github.com/{GITHUB_REPO_OWNER}/{REPO_NAME}.git"

# ===== FOR PRIVATE REPOS (uncomment and add your token) =====
# GITHUB_TOKEN = "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"  # Replace with your token
# REPO_URL = f"https://{GITHUB_REPO_OWNER}:{GITHUB_TOKEN}@github.com/{GITHUB_REPO_OWNER}/{REPO_NAME}.git"

# Clone the repository
if not os.path.exists(REPO_DIR):
    print(f"Cloning repository from {GITHUB_REPO_OWNER}/{REPO_NAME}...")
    # !git clone {REPO_URL} {REPO_DIR}
    print("✅ Repository cloned successfully!")
else:
    print(f"⚠️ Directory '{REPO_DIR}' already exists. Skipping clone.")

# Change to repository directory
# %cd {REPO_DIR}
print(f"✅ Now working in: {os.getcwd()}")

# %% [markdown]
# ## Install Dependencies
#
# Install all required Python packages from requirements.txt

# %%
# Install project dependencies
print("📦 Installing requirements...")
# !pip install -q -r requirements.txt
print("✅ All dependencies installed!")

# %% [markdown]
# ## Download Secrets Configuration (Optional)
#
# If you have a hosted secrets.yaml file (API keys, credentials, etc.), download it here.
# **Skip this cell if not needed.**

# %%
import requests
import os
import yaml

# OPTIONAL: Download secrets.yaml from cloud storage
# Uncomment and modify the URL if you have a hosted secrets file

# SECRETS_URL = "https://your-cloud-storage-url/secrets.yaml"
# SECRETS_PATH = "configs/secrets.yaml"

# try:
#     response = requests.get(SECRETS_URL)
#     response.raise_for_status()
#     
#     os.makedirs(os.path.dirname(SECRETS_PATH), exist_ok=True)
#     
#     with open(SECRETS_PATH, "wb") as f:
#         f.write(response.content)
#     
#     print(f"✅ Secrets file saved to: {SECRETS_PATH}")
#     
#     # Verify contents
#     with open(SECRETS_PATH, "r") as f:
#         cfg = yaml.safe_load(f)
#         print(f"✅ Loaded configuration keys: {list(cfg.keys())}")
# except Exception as e:
#     print(f"⚠️ Could not download secrets: {e}")
#     print("Continue without secrets file...")

print("ℹ️ Secrets download skipped (optional)")

# %% [markdown]
# ## Download Baseline Repositories
#
# Clone the official baseline implementations (Photoguard, MIST, DiffusionGuard)

# %%
# Create baselines directory
# !mkdir -p baselines
# %cd baselines

# Clone Photoguard (if not exists)
if not os.path.exists("photoguard"):
    print("📥 Cloning Photoguard...")
    # !git clone https://github.com/MadryLab/photoguard.git photoguard
    print("✅ Photoguard cloned")
else:
    print("✅ Photoguard already exists")

# Clone MIST (if not exists)
if not os.path.exists("mist"):
    print("📥 Cloning MIST...")
    # !git clone https://github.com/psyker-team/mist.git mist
    print("✅ MIST cloned")
else:
    print("✅ MIST already exists")

# Clone DiffusionGuard (if not exists)
if not os.path.exists("diffusionguard"):
    print("📥 Cloning DiffusionGuard...")
    # !git clone https://github.com/choi403/DiffusionGuard.git diffusionguard
    print("✅ DiffusionGuard cloned")
else:
    print("✅ DiffusionGuard already exists")

# Return to project root
# %cd ..
print(f"✅ All baselines ready in: baselines/")

# %% [markdown]
# ## Verify Setup
#
# Check that all required directories and files are present

# %%
import os

print("🔍 Verifying project structure...\n")

# Check main directories
required_dirs = [
    "configs",
    "datasets", 
    "notebooks",
    "utils",
    "baselines",
    "baselines/photoguard",
    "baselines/mist",
    "baselines/diffusionguard"
]

for directory in required_dirs:
    status = "✅" if os.path.exists(directory) else "❌"
    print(f"{status} {directory}")

# Check key files
required_files = [
    "requirements.txt",
    "configs/phase3.yaml",
    "utils/photoguard.py",
    "utils/mist.py",
    "utils/diffusionguard.py",
    "notebooks/phase3_comparative_evaluation.ipynb"
]

print("\n🔍 Checking key files...\n")
for filepath in required_files:
    status = "✅" if os.path.exists(filepath) else "❌"
    print(f"{status} {filepath}")

print("\n✅ Setup verification complete!")
print(f"Current directory: {os.getcwd()}")

# %% [markdown]
# ## Ready to Run! 🚀
#
# Your environment is now set up. You can proceed to run:
# - `notebooks/phase3_comparative_evaluation.ipynb` for the main comparative experiments
# - Individual phase notebooks in `notebooks/` for specific experiments
#
# **Next steps:**
# 1. Prepare your dataset in `datasets/phase3/`
# 2. Configure parameters in `configs/phase3.yaml`
# 3. Run the Phase 3 notebook for comparative evaluation
